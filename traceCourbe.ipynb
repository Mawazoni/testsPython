# %% [markdown]
# <a href="https://colab.research.google.com/github/Mawazoni/testsPython/blob/main/traceCourbe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def maFonction (x):
  y = (np.log(1+1/x))
  return y

x = np.arange(-500,500,1)
y = []
for e in x:
  y.append(maFonction(e))
y = np.array(y)
plt.plot(x,y)
# Out:
# <ipython-input-5-0b3757840f26>:5: RuntimeWarning: divide by zero encountered in log
#   y = (np.log(1+1/x))
# <ipython-input-5-0b3757840f26>:5: RuntimeWarning: divide by zero encountered in long_scalars
#   y = (np.log(1+1/x))
